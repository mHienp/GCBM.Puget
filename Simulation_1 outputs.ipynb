# %%
import rasterio as rst
from rasterio.plot import show
#from rasterio.mask import mask
#from rasterio.windows import Window, from_bounds

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %% [markdown]
# #### DOM_C

# %%
show(img_Dead_Organic_Matter_C_2010)
show(img_Dead_Organic_Matter_C_2011)
show(img_Dead_Organic_Matter_C_2012)
show(img_Dead_Organic_Matter_C_2013)
show(img_Dead_Organic_Matter_C_2014)
show(img_Dead_Organic_Matter_C_2015)
show(img_Dead_Organic_Matter_C_2016)
show(img_Dead_Organic_Matter_C_2017)
show(img_Dead_Organic_Matter_C_2018)
show(img_Dead_Organic_Matter_C_2019)
show(img_Dead_Organic_Matter_C_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Decomp_Releases

# %%
show(img_Decomp_Releases_2010)
show(img_Decomp_Releases_2011)
show(img_Decomp_Releases_2012)
show(img_Decomp_Releases_2013)
show(img_Decomp_Releases_2014)
show(img_Decomp_Releases_2015)
show(img_Decomp_Releases_2016)
show(img_Decomp_Releases_2017)
show(img_Decomp_Releases_2018)
show(img_Decomp_Releases_2019)
show(img_Decomp_Releases_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Delta_Total_DOM

# %%
show(img_Delta_Total_DOM_2010)
show(img_Delta_Total_DOM_2011)
show(img_Delta_Total_DOM_2012)
show(img_Delta_Total_DOM_2013)
show(img_Delta_Total_DOM_2014)
show(img_Delta_Total_DOM_2015)
show(img_Delta_Total_DOM_2016)
show(img_Delta_Total_DOM_2017)
show(img_Delta_Total_DOM_2018)
show(img_Delta_Total_DOM_2019)
show(img_Delta_Total_DOM_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Delta_Total_Ecosystem

# %%
show(img_Delta_Total_Ecosystem_2010)
show(img_Delta_Total_Ecosystem_2011)
show(img_Delta_Total_Ecosystem_2012)
show(img_Delta_Total_Ecosystem_2013)
show(img_Delta_Total_Ecosystem_2014)
show(img_Delta_Total_Ecosystem_2015)
show(img_Delta_Total_Ecosystem_2016)
show(img_Delta_Total_Ecosystem_2017)
show(img_Delta_Total_Ecosystem_2018)
show(img_Delta_Total_Ecosystem_2019)
show(img_Delta_Total_Ecosystem_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Ecosystem_Removals

# %%
show(img_Ecosystem_Removals_2010)
show(img_Ecosystem_Removals_2011)
show(img_Ecosystem_Removals_2012)
show(img_Ecosystem_Removals_2013)
show(img_Ecosystem_Removals_2014)
show(img_Ecosystem_Removals_2015)
show(img_Ecosystem_Removals_2016)
show(img_Ecosystem_Removals_2017)
show(img_Ecosystem_Removals_2018)
show(img_Ecosystem_Removals_2019)
show(img_Ecosystem_Removals_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### NBP

# %%
show(img_NBP_2010)
show(img_NBP_2011)
show(img_NBP_2012)
show(img_NBP_2013)
show(img_NBP_2014)
show(img_NBP_2015)
show(img_NBP_2016)
show(img_NBP_2017)
show(img_NBP_2018)
show(img_NBP_2019)
show(img_NBP_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### NEP

# %%
show(img_NEP_2010)
show(img_NEP_2011)
show(img_NEP_2012)
show(img_NEP_2013)
show(img_NEP_2014)
show(img_NEP_2015)
show(img_NEP_2016)
show(img_NEP_2017)
show(img_NEP_2018)
show(img_NEP_2019)
show(img_NEP_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Soil C

# %%
show(img_Soil_C_2010)
show(img_Soil_C_2011)
show(img_Soil_C_2012)
show(img_Soil_C_2013)
show(img_Soil_C_2014)
show(img_Soil_C_2015)
show(img_Soil_C_2016)
show(img_Soil_C_2017)
show(img_Soil_C_2018)
show(img_Soil_C_2019)
show(img_Soil_C_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_CO2_Emissions

# %%
show(img_Total_CO2_Emissions_2010)
show(img_Total_CO2_Emissions_2011)
show(img_Total_CO2_Emissions_2012)
show(img_Total_CO2_Emissions_2013)
show(img_Total_CO2_Emissions_2014)
show(img_Total_CO2_Emissions_2015)
show(img_Total_CO2_Emissions_2016)
show(img_Total_CO2_Emissions_2017)
show(img_Total_CO2_Emissions_2018)
show(img_Total_CO2_Emissions_2019)
show(img_Total_CO2_Emissions_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_DOM_Emissions

# %%
show(img_Total_DOM_Emissions_2010)
show(img_Total_DOM_Emissions_2011)
show(img_Total_DOM_Emissions_2012)
show(img_Total_DOM_Emissions_2013)
show(img_Total_DOM_Emissions_2014)
show(img_Total_DOM_Emissions_2015)
show(img_Total_DOM_Emissions_2016)
show(img_Total_DOM_Emissions_2017)
show(img_Total_DOM_Emissions_2018)
show(img_Total_DOM_Emissions_2019)
show(img_Total_DOM_Emissions_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_Ecosystem_C

# %%
show(img_Total_Ecosystem_C_2010)
show(img_Total_Ecosystem_C_2011)
show(img_Total_Ecosystem_C_2012)
show(img_Total_Ecosystem_C_2013)
show(img_Total_Ecosystem_C_2014)
show(img_Total_Ecosystem_C_2015)
show(img_Total_Ecosystem_C_2016)
show(img_Total_Ecosystem_C_2017)
show(img_Total_Ecosystem_C_2018)
show(img_Total_Ecosystem_C_2019)
show(img_Total_Ecosystem_C_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total Emissions

# %%
show(img_Total_Emissions_2010)
show(img_Total_Emissions_2011)
show(img_Total_Emissions_2012)
show(img_Total_Emissions_2013)
show(img_Total_Emissions_2014)
show(img_Total_Emissions_2015)
show(img_Total_Emissions_2016)
show(img_Total_Emissions_2017)
show(img_Total_Emissions_2018)
show(img_Total_Emissions_2019)
show(img_Total_Emissions_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### AGB_C

# %%
show(img_AG_Biomass_C_2010)
show(img_AG_Biomass_C_2011)
show(img_AG_Biomass_C_2012)
show(img_AG_Biomass_C_2013)
show(img_AG_Biomass_C_2014)
show(img_AG_Biomass_C_2015)
show(img_AG_Biomass_C_2016)
show(img_AG_Biomass_C_2017)
show(img_AG_Biomass_C_2018)
show(img_AG_Biomass_C_2019)
show(img_AG_Biomass_C_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Bio to DOM from disturbances

# %%
show(img_Bio_To_DOM_From_Disturbances_2010)
show(img_Bio_To_DOM_From_Disturbances_2011)
show(img_Bio_To_DOM_From_Disturbances_2012)
show(img_Bio_To_DOM_From_Disturbances_2013)
show(img_Bio_To_DOM_From_Disturbances_2014)
show(img_Bio_To_DOM_From_Disturbances_2015)
show(img_Bio_To_DOM_From_Disturbances_2016)
show(img_Bio_To_DOM_From_Disturbances_2017)
show(img_Bio_To_DOM_From_Disturbances_2018)
show(img_Bio_To_DOM_From_Disturbances_2019)
show(img_Bio_To_DOM_From_Disturbances_2020)
# Out:
# <AxesSubplot:>

# %%
show(img_Delta_Total_Biomass_2010)
show(img_Delta_Total_Biomass_2011)
show(img_Delta_Total_Biomass_2012)
show(img_Delta_Total_Biomass_2013)
show(img_Delta_Total_Biomass_2014)
show(img_Delta_Total_Biomass_2015)
show(img_Delta_Total_Biomass_2016)
show(img_Delta_Total_Biomass_2017)
show(img_Delta_Total_Biomass_2018)
show(img_Delta_Total_Biomass_2019)
show(img_Delta_Total_Biomass_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### NPP

# %%
show(img_NPP_2010)
show(img_NPP_2011)
show(img_NPP_2012)
show(img_NPP_2013)
show(img_NPP_2014)
show(img_NPP_2015)
show(img_NPP_2016)
show(img_NPP_2017)
show(img_NPP_2018)
show(img_NPP_2019)
show(img_NPP_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_Biomass_C

# %%
show(img_Total_Biomass_C_2010)
show(img_Total_Biomass_C_2011)
show(img_Total_Biomass_C_2012)
show(img_Total_Biomass_C_2013)
show(img_Total_Biomass_C_2014)
show(img_Total_Biomass_C_2015)
show(img_Total_Biomass_C_2016)
show(img_Total_Biomass_C_2017)
show(img_Total_Biomass_C_2018)
show(img_Total_Biomass_C_2019)
show(img_Total_Biomass_C_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_Biomass_Emissions

# %%
show(img_Total_Biomass_Emissions_2010)
show(img_Total_Biomass_Emissions_2011)
show(img_Total_Biomass_Emissions_2012)
show(img_Total_Biomass_Emissions_2013)
show(img_Total_Biomass_Emissions_2014)
show(img_Total_Biomass_Emissions_2015)
show(img_Total_Biomass_Emissions_2016)
show(img_Total_Biomass_Emissions_2017)
show(img_Total_Biomass_Emissions_2018)
show(img_Total_Biomass_Emissions_2019)
show(img_Total_Biomass_Emissions_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_CH4_Emissions

# %%
show(img_Total_CH4_Emissions_2010)
show(img_Total_CH4_Emissions_2011)
show(img_Total_CH4_Emissions_2012)
show(img_Total_CH4_Emissions_2013)
show(img_Total_CH4_Emissions_2014)
show(img_Total_CH4_Emissions_2015)
show(img_Total_CH4_Emissions_2016)
show(img_Total_CH4_Emissions_2017)
show(img_Total_CH4_Emissions_2018)
show(img_Total_CH4_Emissions_2019)
show(img_Total_CH4_Emissions_2020)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Total_CO_Emissions

# %%
show(img_Total_CO_Emissions_2010)
show(img_Total_CO_Emissions_2011)
show(img_Total_CO_Emissions_2012)
show(img_Total_CO_Emissions_2013)
show(img_Total_CO_Emissions_2014)
show(img_Total_CO_Emissions_2015)
show(img_Total_CO_Emissions_2016)
show(img_Total_CO_Emissions_2017)
show(img_Total_CO_Emissions_2018)
show(img_Total_CO_Emissions_2019)
show(img_Total_CO_Emissions_2020)
# Out:
# <AxesSubplot:>
